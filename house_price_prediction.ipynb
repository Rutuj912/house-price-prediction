# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('house_data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[298323.25 304319.  ]
#  [355438.93 351806.  ]
#  [334718.9  320799.  ]
#  [491022.11 485228.  ]
#  [135987.08 130237.  ]
#  [397090.92 399439.  ]
#  [134357.48 115136.  ]
#  [527866.84 521007.  ]
#  [532863.65 531546.  ]
#  [471855.92 464397.  ]
#  [430348.31 435149.  ]
#  [199804.46 188314.  ]
#  [403315.86 395923.  ]
#  [656561.65 657192.  ]
#  [484285.86 496399.  ]
#  [666314.14 671113.  ]
#  [656815.86 685589.  ]
#  [464752.74 464834.  ]
#  [236835.86 232297.  ]
#  [200655.02 206242.  ]]

# %%
squarefoot = float(input("Enter square footage: "))
bedrooms = int(input("Enter number of bedrooms: "))
bathrooms = int(input("Enter number of bathrooms: "))

new_data = np.array([[squarefoot, bedrooms, bathrooms]])
predicted_price = regressor.predict(new_data)

print(f"Predicted House Price: ₹{predicted_price[0]:,.2f}")
# Out:
# Enter square footage: 1360
# Enter number of bedrooms: 5
# Enter number of bathrooms: 2
# Predicted House Price: ₹284,102.29

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R² Score:", r2)
# Out:
# R² Score: 0.996350353648725

# %%
plt.scatter(y_pred, y_test, color = 'red')
plt.plot(y_pred, regressor.predict(X_test), color = 'blue')
plt.title('original vs predicted')
plt.xlabel('original price')
plt.ylabel('predicted price')
plt.show()
